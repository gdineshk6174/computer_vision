# %%
import keras
from keras import layers
import numpy as np

latent_dim = 32
height = 32
width = 32
channels = 3

generator_input = keras.Input(shape=(latent_dim,))

# First, transform the input into a 16x16 128-channels feature map
x = layers.Dense(128 * 16 * 16)(generator_input)
x = layers.LeakyReLU()(x)
x = layers.Reshape((16, 16, 128))(x)

# Then, add a convolution layer
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Upsample to 32x32
x = layers.Conv2DTranspose(256, 4, strides=2, padding='same')(x)
x = layers.LeakyReLU()(x)

# Few more conv layers
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(256, 5, padding='same')(x)
x = layers.LeakyReLU()(x)

# Produce a 32x32 1-channel feature map
x = layers.Conv2D(channels, 7, activation='tanh', padding='same')(x)
generator = keras.models.Model(generator_input, x)
generator.summary()
# Out:
# Using TensorFlow backend.
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         (None, 32)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 32768)             1081344
# _________________________________________________________________
# leaky_re_lu_1 (LeakyReLU)    (None, 32768)             0
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 16, 16, 128)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 16, 16, 256)       819456
# _________________________________________________________________
# leaky_re_lu_2 (LeakyReLU)    (None, 16, 16, 256)       0
# _________________________________________________________________
# conv2d_transpose_1 (Conv2DTr (None, 32, 32, 256)       1048832
# _________________________________________________________________
# leaky_re_lu_3 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_4 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 32, 32, 256)       1638656
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 32, 32, 256)       0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 32, 32, 3)         37635
# =================================================================
# Total params: 6,264,579
# Trainable params: 6,264,579
# Non-trainable params: 0
# _________________________________________________________________

# %%
discriminator_input = layers.Input(shape=(height, width, channels))
x = layers.Conv2D(128, 3)(discriminator_input)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Conv2D(128, 4, strides=2)(x)
x = layers.LeakyReLU()(x)
x = layers.Flatten()(x)

# One dropout layer - important trick!
x = layers.Dropout(0.4)(x)

# Classification layer
x = layers.Dense(1, activation='sigmoid')(x)

discriminator = keras.models.Model(discriminator_input, x)
discriminator.summary()

# To stabilize training, we use learning rate decay
# and gradient clipping (by value) in the optimizer.
discriminator_optimizer = keras.optimizers.RMSprop(lr=0.0008, clipvalue=1.0, decay=1e-8)
discriminator.compile(optimizer=discriminator_optimizer, loss='binary_crossentropy')
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 32, 32, 3)         0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 30, 30, 128)       3584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 30, 30, 128)       0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 14, 14, 128)       262272
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 14, 14, 128)       0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 6, 6, 128)         262272
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 6, 6, 128)         0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 2, 2, 128)         262272
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 513
# =================================================================
# Total params: 790,913
# Trainable params: 790,913
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Set discriminator weights to non-trainable
# (will only apply to the `gan` model)
discriminator.trainable = False

gan_input = keras.Input(shape=(latent_dim,))
gan_output = discriminator(generator(gan_input))
gan = keras.models.Model(gan_input, gan_output)

gan_optimizer = keras.optimizers.RMSprop(lr=0.0004, clipvalue=1.0, decay=1e-8)
gan.compile(optimizer=gan_optimizer, loss='binary_crossentropy')

# %%
# !mkdir my_dir

# %%
# !ls
# Out:
# my_dir	sample_data

# %%
import os
from keras.preprocessing import image

# Load CIFAR10 data
(x_train, y_train), (_, _) = keras.datasets.cifar10.load_data()

# Select frog images (class 6)
x_train = x_train[y_train.flatten() == 6]

# Normalize data
x_train = x_train.reshape(
    (x_train.shape[0],) + (height, width, channels)).astype('float32') / 255.

iterations = 10000
batch_size = 20
save_dir = ''

# Start training loop
start = 0
for step in range(iterations):
    # Sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Decode them to fake images
    generated_images = generator.predict(random_latent_vectors)

    # Combine them with real images
    stop = start + batch_size
    real_images = x_train[start: stop]
    combined_images = np.concatenate([generated_images, real_images])

    # Assemble labels discriminating real from fake images
    labels = np.concatenate([np.ones((batch_size, 1)),
                             np.zeros((batch_size, 1))])
    # Add random noise to the labels - important trick!
    labels += 0.05 * np.random.random(labels.shape)

    # Train the discriminator
    d_loss = discriminator.train_on_batch(combined_images, labels)

    # sample random points in the latent space
    random_latent_vectors = np.random.normal(size=(batch_size, latent_dim))

    # Assemble labels that say "all real images"
    misleading_targets = np.zeros((batch_size, 1))

    # Train the generator (via the gan model,
    # where the discriminator weights are frozen)
    a_loss = gan.train_on_batch(random_latent_vectors, misleading_targets)
    
    start += batch_size
    if start > len(x_train) - batch_size:
      start = 0

    # Occasionally save / plot
    if step % 100 == 0:
        # Save model weights
        gan.save_weights('gan.h5')

        # Print metrics
        print('discriminator loss at step %s: %s' % (step, d_loss))
        print('adversarial loss at step %s: %s' % (step, a_loss))

        # Save one generated image
        img = image.array_to_img(generated_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'generated_frog' + str(step) + '.png'))

        # Save one real image, for comparison
        img = image.array_to_img(real_images[0] * 255., scale=False)
        img.save(os.path.join(save_dir, 'real_frog' + str(step) + '.png'))
# Out:
# Downloading data from https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz
# 170500096/170498071 [==============================] - 13s 0us/step
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:975: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# WARNING:tensorflow:Variable *= will be deprecated. Use `var.assign(var * other)` if you want assignment to the variable value or `x = x * y` if you want a new python Tensor object.
# discriminator loss at step 0: 0.69016916
# adversarial loss at step 0: 0.6634017
# discriminator loss at step 100: 0.6786802
# adversarial loss at step 100: 0.7373277
# discriminator loss at step 200: 0.68493617
# adversarial loss at step 200: 0.7727581
# discriminator loss at step 300: 0.71113634
# adversarial loss at step 300: 0.7268663
# discriminator loss at step 400: 0.6829671
# adversarial loss at step 400: 0.80869925
# discriminator loss at step 500: 0.69818974
# adversarial loss at step 500: 0.74148405
# discriminator loss at step 600: 0.6945461
# adversarial loss at step 600: 0.7274214
# discriminator loss at step 700: 0.6919905
# adversarial loss at step 700: 0.85778695
# discriminator loss at step 800: 0.7351163
# adversarial loss at step 800: 0.77392536
# discriminator loss at step 900: 0.695217
# adversarial loss at step 900: 0.7513082
# discriminator loss at step 1000: 0.6983227
# adversarial loss at step 1000: 0.78738576
# discriminator loss at step 1100: 0.70704687
# adversarial loss at step 1100: 0.73561776
# discriminator loss at step 1200: 0.6694104
# adversarial loss at step 1200: 0.7357442
# discriminator loss at step 1300: 0.69464576
# adversarial loss at step 1300: 0.7555252
# discriminator loss at step 1400: 0.68813765
# adversarial loss at step 1400: 0.7696568
# discriminator loss at step 1500: 0.7323599
# adversarial loss at step 1500: 0.75968504
# discriminator loss at step 1600: 0.7051633
# adversarial loss at step 1600: 0.71005267
# discriminator loss at step 1700: 0.6927495
# adversarial loss at step 1700: 0.8032519
# discriminator loss at step 1800: 0.714309
# adversarial loss at step 1800: 0.7414323
# discriminator loss at step 1900: 0.69050586
# adversarial loss at step 1900: 0.75719386
# discriminator loss at step 2000: 0.6925147
# adversarial loss at step 2000: 0.74077046
# discriminator loss at step 2100: 0.6897459
# adversarial loss at step 2100: 0.74530554
# discriminator loss at step 2200: 0.6939489
# adversarial loss at step 2200: 0.74770105
# discriminator loss at step 2300: 0.70663255
# adversarial loss at step 2300: 0.75706565
# discriminator loss at step 2400: 0.6938832
# adversarial loss at step 2400: 0.76034665
# discriminator loss at step 2500: 0.7008003
# adversarial loss at step 2500: 0.72988516
# discriminator loss at step 2600: 0.7057613
# adversarial loss at step 2600: 0.75138
# discriminator loss at step 2700: 0.6975782
# adversarial loss at step 2700: 0.7519782
# discriminator loss at step 2800: 0.68454593
# adversarial loss at step 2800: 0.7562562
# discriminator loss at step 2900: 0.7257727
# adversarial loss at step 2900: 0.7466126
# discriminator loss at step 3000: 0.6873953
# adversarial loss at step 3000: 0.7599256
# discriminator loss at step 3100: 0.6917421
# adversarial loss at step 3100: 0.77573234
# discriminator loss at step 3200: 0.69950753
# adversarial loss at step 3200: 0.7401924
# discriminator loss at step 3300: 0.702471
# adversarial loss at step 3300: 0.7608892
# discriminator loss at step 3400: 0.700775
# adversarial loss at step 3400: 0.80948913
# discriminator loss at step 3500: 0.68174994
# adversarial loss at step 3500: 0.73143786
# discriminator loss at step 3600: 1.5664154
# adversarial loss at step 3600: 0.7692815
# discriminator loss at step 3700: 0.69433
# adversarial loss at step 3700: 0.77218264
# discriminator loss at step 3800: 0.68486154
# adversarial loss at step 3800: 0.70152843
# discriminator loss at step 3900: 0.69974834
# adversarial loss at step 3900: 0.7524315
# discriminator loss at step 4000: 0.6972165
# adversarial loss at step 4000: 0.7658458
# discriminator loss at step 4100: 0.66457
# adversarial loss at step 4100: 1.4335268
# discriminator loss at step 4200: 0.70637894
# adversarial loss at step 4200: 0.74902546
# discriminator loss at step 4300: 0.6903292
# adversarial loss at step 4300: 0.72627985
# discriminator loss at step 4400: 0.7020756
# adversarial loss at step 4400: 0.80650747
# discriminator loss at step 4500: 0.6800076
# adversarial loss at step 4500: 0.7240731
# discriminator loss at step 4600: 0.6712693
# adversarial loss at step 4600: 0.74541014
# discriminator loss at step 4700: 0.7131176
# adversarial loss at step 4700: 0.6466877
# discriminator loss at step 4800: 0.6655479
# adversarial loss at step 4800: 0.72049576
# discriminator loss at step 4900: 0.6847947
# adversarial loss at step 4900: 0.63992393
# discriminator loss at step 5000: 0.70256215
# adversarial loss at step 5000: 0.7298635
# discriminator loss at step 5100: 0.69745255
# adversarial loss at step 5100: 0.896678
# discriminator loss at step 5200: 0.7171258
# adversarial loss at step 5200: 0.96224517
# discriminator loss at step 5300: 0.73042804
# adversarial loss at step 5300: 0.7790502
# discriminator loss at step 5400: 0.67535156
# adversarial loss at step 5400: 0.9128747
# discriminator loss at step 5500: 0.9307001
# adversarial loss at step 5500: 0.87654114
# discriminator loss at step 5600: 0.67833775
# adversarial loss at step 5600: 0.6799964
# discriminator loss at step 5700: 0.7835995
# adversarial loss at step 5700: 0.93913764
# discriminator loss at step 5800: 0.67240983
# adversarial loss at step 5800: 0.96647596
# discriminator loss at step 5900: 0.6867771
# adversarial loss at step 5900: 0.8121645
# discriminator loss at step 6000: 0.52735966
# adversarial loss at step 6000: 11.4541025
# discriminator loss at step 6100: 0.72071
# adversarial loss at step 6100: 0.8413933
# discriminator loss at step 6200: 0.7183698
# adversarial loss at step 6200: 0.7439647
# discriminator loss at step 6300: 0.7303637
# adversarial loss at step 6300: 0.8648263
# discriminator loss at step 6400: 0.6862754
# adversarial loss at step 6400: 1.0272214
# discriminator loss at step 6500: 0.7009756
# adversarial loss at step 6500: 0.71676457
# discriminator loss at step 6600: 0.7344175
# adversarial loss at step 6600: 0.78776675
# discriminator loss at step 6700: 0.6971735
# adversarial loss at step 6700: 0.73221666
# discriminator loss at step 6800: 0.66100436
# adversarial loss at step 6800: 0.73819447
# discriminator loss at step 6900: 0.6925324
# adversarial loss at step 6900: 0.9576582
# discriminator loss at step 7000: 0.6812218
# adversarial loss at step 7000: 0.7617838
# discriminator loss at step 7100: 0.68361574
# adversarial loss at step 7100: 0.7618381
# discriminator loss at step 7200: 0.68853194
# adversarial loss at step 7200: 0.74190027
# discriminator loss at step 7300: 0.62246877
# adversarial loss at step 7300: 0.9453925
# discriminator loss at step 7400: 0.69837344
# adversarial loss at step 7400: 0.93133515
# discriminator loss at step 7500: 0.6686889
# adversarial loss at step 7500: 0.90736264
# discriminator loss at step 7600: 0.6891251
# adversarial loss at step 7600: 0.7438405
# discriminator loss at step 7700: 0.6834837
# adversarial loss at step 7700: 0.72989726
# discriminator loss at step 7800: 0.6842101
# adversarial loss at step 7800: 0.9455271
# discriminator loss at step 7900: 0.71494895
# adversarial loss at step 7900: 1.3124841
# discriminator loss at step 8000: 0.7040452
# adversarial loss at step 8000: 0.74499303
# discriminator loss at step 8100: 0.6707948
# adversarial loss at step 8100: 0.7882352
# discriminator loss at step 8200: 0.6963291
# adversarial loss at step 8200: 0.801297
# discriminator loss at step 8300: 0.667158
# adversarial loss at step 8300: 0.7999321
# discriminator loss at step 8400: 0.6966737
# adversarial loss at step 8400: 0.76773465
# discriminator loss at step 8500: 0.6742609
# adversarial loss at step 8500: 0.824292
# discriminator loss at step 8600: 0.68517417
# adversarial loss at step 8600: 0.7412793
# discriminator loss at step 8700: 0.67327535
# adversarial loss at step 8700: 0.91855943
# discriminator loss at step 8800: 0.687051
# adversarial loss at step 8800: 0.7481664
# discriminator loss at step 8900: 0.96040404
# adversarial loss at step 8900: 1.2304921
# discriminator loss at step 9000: 0.68048495
# adversarial loss at step 9000: 0.82220334
# discriminator loss at step 9100: 0.6860633
# adversarial loss at step 9100: 0.73040736
# discriminator loss at step 9200: 0.6861399
# adversarial loss at step 9200: 0.71671444
# discriminator loss at step 9300: 0.6715218
# adversarial loss at step 9300: 0.79351634
# discriminator loss at step 9400: 0.6958596
# adversarial loss at step 9400: 0.9122337
# discriminator loss at step 9500: 0.67488694
# adversarial loss at step 9500: 0.81662846
# discriminator loss at step 9600: 0.6924977
# adversarial loss at step 9600: 0.85525864
# discriminator loss at step 9700: 0.6855623
# adversarial loss at step 9700: 0.8872379
# discriminator loss at step 9800: 0.65435004
# adversarial loss at step 9800: 1.2696117
# discriminator loss at step 9900: 0.7704562
# adversarial loss at step 9900: 0.77063745

# %%
import matplotlib.pyplot as plt

# Sample random points in the latent space
random_latent_vectors = np.random.normal(size=(10, latent_dim))

# Decode them to fake images
generated_images = generator.predict(random_latent_vectors)

for i in range(generated_images.shape[0]):
    img = image.array_to_img(generated_images[i] * 255., scale=False)
    plt.figure()
    plt.imshow(img)
    
plt.show()
